# %% [markdown]
# # Estruturas Condicionais / Desvio Condicional

# %%
nome=input("Digite seu nome: ")
ano_nasc=int(input(f"{nome}, digite seu ano de nascimento: "))

# %%
idade=2026-ano_nasc

# %%
if idade >= 18:
    print(f"{nome}, vc é maior de idade")
elif idade >= 16:
     print(f"{nome}, vc é adolescente de idade")
else:
    print(f"{nome}, vc é menor de idade")
# Out:
# pet, vc é maior de idade
