# %%
inteiro=10
ponto_flutuante=3.14
numero_complexo=2+3j

print(type(inteiro))
print(type(ponto_flutuante))
print(type(numero_complexo))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %% [markdown]
# ## Testando as strings

# %%
nome="Pet"

# %%
cep= "25645-045"

# %%
logadouro="""Rua Sao sebastiao, 222
bairro: sao sebastiao
cdd: petropolis
estado: Rj"""

# %%
print(nome)
# Out:
# Pet

# %%
print(cep)
# Out:
# 25645-045

# %%
print(logadouro)
# Out:
# Rua Sao sebastiao, 222
# bairro: sao sebastiao
# cdd: petropolis
# estado: Rj

# %% [markdown]
# ## Variaveis booleanas

# %%
numero1=5
numero2=10

# %%
resultado=numero1 > numero2

# %%
resultado2=numero1 < numero2

# %%
print(resultado)
# Out:
# False

# %%
print(resultado2)
# Out:
# True

# %% [markdown]
# ## Listas - Tuplas e Ranges

# %%
tupla=(1,2)
type(tupla)
# Out:
# tuple

# %%
lista=[1,2]
type(lista)
# Out:
# list

# %%
print(tupla[1])
# Out:
# 2

# %%
print(lista)
# Out:
# [1, 2]

# %%
tupla[1]=3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 tupla[1]=3
#
# TypeError: 'tuple' object does not support item assignment

# %%
lista[1]=3

# %%
print(lista)
# Out:
# [1, 3]

# %%
lista.append(4)
lista.append(5)

# %%
print(lista)
# Out:
# [1, 3, 4, 5]

# %%
lista=list(range(1,10,2))
print(lista)
# Out:
# [1, 3, 5, 7, 9]
