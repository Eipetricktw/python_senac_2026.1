# %% [markdown]
# # aula 4

# %% [markdown]
# ## Contagem

# %%
meu_livro="Python para iniciantes"
print(meu_livro)

meu_livro="Algoritmo Divertidos"
print(meu_livro)

PI=3.14159
Gravidade=9.8
# Out:
# Python para iniciantes
# Algoritmo Divertidos

# %%
nome=input("Qual o seu nome?")
print("Seu nome é" ,nome)
# Out:
# Seu nome é Pet

# %%
nascimento=input("Qual o seu ano de nascimento?")

# %%
nascimento_int=int(nascimento)
idade=( 2026 - nascimento_int)
print(f"Ola {nome} sua idade é {idade}")
# Out:
# Ola Pet sua idade é 25
