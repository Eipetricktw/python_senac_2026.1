# %% [markdown]
# # Aula 03 -  Variaveis

# %% [markdown]
# ## olá mundo!

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ## Tipos de variaveis

# %%
numero = 15
numero_frac = 15,2
text = "Pet"
# Out:
# textos: 15 (15, 2) Pet

# %%
type(numero_frac)
# Out:
# tuple

# %%
print(type(numero))
print(type(numero_frac))
print(type(text))
# Out:
# <class 'int'>
# <class 'tuple'>
# <class 'str'>

# %%
print(text.upper())
print(text.lower())
# Out:
# PET
# pet

# %%
numero+numero
# Out:
# 30

# %%
idade_num = int(input("Digite sua idade"))

# %%
type(idade_num)
# Out:
# int
