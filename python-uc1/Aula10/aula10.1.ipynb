# %% [markdown]
# # Aula 10

# %%
# Criando uma matriz 3x3
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# %%
print("Elementos (0,0):", matriz[0][0]) #Saida: 1
print("Elementos (3,1):", matriz[2][2]) #Saida: 9
# Out:
# Elementos (0,0): 1
# Elementos (3,1): 9

# %%
import random
QTD_LINHAS=4
QTD_COLUNAS=5
matriz=[]

for linha in range(QTD_LINHAS):
    linha=[]
    for coluna in range(QTD_COLUNAS):
        linha.append(random.randint(1, 100))
    matriz.append(linha)

print(matriz)
# Out:
# [[37, 76, 64, 37, 99], [2, 97, 95, 85, 46], [44, 96, 50, 13, 15], [6, 49, 10, 56, 29]]

# %%
for linha in matriz:
    for elemento in linha:
        print(f"{elemento:03d}", end="\t")
    print()
# Out:
# 037	076	064	037	099
# 002	097	095	085	046
# 044	096	050	013	015
# 006	049	010	056	029

# %%
matriz=[]

for i in range(4):
    linha=[]
    for j in range(4):
        valor= int(input(f"Digite o valor para [{i}][{j}]: "))
        linha.append(valor)
    matriz.append(linha)

for linha in matriz:
    print(linha)
# Out:
# [1, 2, 1, 2]
# [1, 2, 1, 2]
# [1, 2, 1, 2]
# [1, 2, 1, 2]

# %%
matriz=[]
import random
QTD_LINHAS=4
QTD_COLUNAS=5
matriz=[]

for linha in range(QTD_LINHAS):
    linha=[]
    for coluna in range(QTD_COLUNAS):
        linha.append(random.randint(1, 100))
    matriz.append(linha)
    
for linha in matriz:
    print(linha)
# Out:
# [92, 29, 3, 96, 85]
# [59, 32, 44, 17, 22]
# [72, 7, 67, 65, 33]
# [9, 83, 15, 29, 59]

# %%
import random

def criar_matriz(qt_linhas=4, qt_colunas=4):
    matriz=[]
    for _linha in range(qt_linhas):
        linha=[]
        for _coluna in range (qt_colunas):
            linha.append(random.randint(1, 100))
        matriz.append(linha)

    return (matriz)

matriz=criar_matriz(5, 5)

for linha in matriz:
    print(linha)
# Out:
# [57, 40, 38, 88, 23]
# [96, 11, 27, 77, 33]
# [62, 76, 90, 35, 65]
# [65, 77, 45, 95, 56]
# [72, 90, 46, 83, 20]

# %% [markdown]
# # Aula 10.2

# %%
def imprime_matriz(matriz=[]):
    for linha in matriz:        
        for elemento in linha :
            print(f"{elemento:4d}",end=" ")
        print()
    print(linha)

# %%
minha_matriz=criar_matriz(6, 7)

# %%
imprime_matriz(minha_matriz)
# Out:
#   58   70   93   89   81   64   91
#   98  100    7   52   38   11   46
#   10   66   25   87    5   15    9
#   65   31   47   64   12   41   25
#   99   40   69   59   22   56   76
#   21   93    4   32   46   71   12
# [21, 93, 4, 32, 46, 71, 12]

# %%
def imprime_matriz_v2(matriz=[]):
    if isinstance(matriz,list):    
        for linha in matriz: 
            if isinstance(linha, list):
                for elemento in linha :
                    print(f"{elemento:4d}",end=" ")
                print()
        else:
            print("[erro]")

# %%
matriz="123"
imprime_matriz_v2(matriz)

# %% [markdown]
# # Aula 10.3

# %%
linha_atual=1
for linha in minha_matriz :
    #print(max(linha))
    print(f"O maior valor da {linha_atual}a. é {max(linha)}")
    linha_atual+=1
# Out:
# O maior valor da 1a. é 93
# O maior valor da 2a. é 100
# O maior valor da 3a. é 87
# O maior valor da 4a. é 65
# O maior valor da 5a. é 99
# O maior valor da 6a. é 93

# %%
linha_atual=1
for linha in minha_matriz :
    #print(max(linha))
    print(f"O maior valor da {linha_atual}a. é {max(linha)}")
    linha_atual+=1
# Out:
# O maior valor da 1a. é 93
# O maior valor da 2a. é 100
# O maior valor da 3a. é 87
# O maior valor da 4a. é 65
# O maior valor da 5a. é 99
# O maior valor da 6a. é 93
