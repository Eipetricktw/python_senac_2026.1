# %% [markdown]
# # Modulos

# %%
import math

# %%
raiz=math.sqrt(4)

# %%
print(raiz)
# Out:
# 2.0

# %%
from math import sqrt

# %%
raiz=sqrt(25)
print(raiz)
# Out:
# 5.0

# %% [markdown]
# # Importando um modulo

# %%
import meu_modulo

# %%
meu_modulo.saudacao("LRodriggo")
# Out:
# Ola, LRodriggo
